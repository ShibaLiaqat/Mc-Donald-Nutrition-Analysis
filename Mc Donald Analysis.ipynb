# %% [markdown]
# # Mc Donald Analysis

# %% [markdown]
# ### import library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# ### Load Data set

# %%
McD = pd.read_csv("D:\Greatlearning\Python\Mcdonald .csv")

# %%
McD.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
McD.tail()
# Out:
#                Category                                               Item  \
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# ...

# %%
McD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
# No missing data

# %%
McD.describe(include = "all")
# Out:
#             Category          Item  Serving Size     Calories  \
# count            260           260           260   260.000000
# unique             9           260           107          NaN
# top     Coffee & Tea  Egg McMuffin  16 fl oz cup          NaN
# freq              95             1            45          NaN
# mean             NaN           NaN           NaN   368.269231
# std              NaN           NaN           NaN   240.269886
# min              NaN           NaN           NaN     0.000000
# 25%              NaN           NaN           NaN   210.000000
# 50%              NaN           NaN           NaN   340.000000
# 75%              NaN           NaN           NaN   500.000000
# max              NaN           NaN           NaN  1880.000000
#
#         Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count          260.000000  260.000000                 260.000000
# unique                NaN         NaN                        NaN
# ...

# %%
McD.shape
# Out:
# (260, 24)

# %% [markdown]
# ## Check which category has highest varieties and least varieties

# %%
sns.countplot( y ="Category", data= McD, order = McD["Category"].value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
# Coffee and Tea have the maximum varieties while snacks and sides have the least

# %%
plt.figure(figsize=(25,25))
sns.boxplot(McD, orient = "h" )
# Out:
# <Axes: >

# %%
sns.boxplot(data=McD[['Calories','Calories from Fat','Total Fat','Total Fat (% Daily Value)']], orient = "h" )
plt.show()

# %%
sns.boxplot(data=McD[['Saturated Fat','Saturated Fat (% Daily Value)' ,'Trans Fat']], orient = "h" )
plt.show()

# %%
sns.boxplot(data=McD[['Cholesterol','Cholesterol (% Daily Value)']], orient = "h" )
plt.show()

# %%
sns.boxplot(data=McD[['Calories','Calories from Fat','Total Fat','Total Fat (% Daily Value)']], orient = "h" )
plt.show()

# %%
sns.boxplot(data=McD[['Sodium','Sodium (% Daily Value)']], orient = "h" )
plt.show()

# %%
sns.boxplot(data=McD[['Carbohydrates', 'Carbohydrates (% Daily Value)']], orient = "h" )
plt.show()

# %%
sns.boxplot(data=McD[['Sugars', 'Protein']], orient = "h" )
plt.show()

# %%
sns.boxplot(data=McD[['Dietary Fiber', 'Dietary Fiber (% Daily Value)']], orient = "h" )
plt.show()

# %% [markdown]
# ## Which variables have the highest correlation?

# %%
cor=McD.corr()
plt.figure(figsize=(15, 15))
sns.heatmap(cor,annot = True, vmin=-1, vmax=1, center= 0)
# Out:
# C:\Users\shiba\AppData\Local\Temp\ipykernel_22312\1145986243.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=McD.corr()
# <Axes: >

# %% [markdown]
# As per the heatmap above and the correlation matrix, the variable with the highest correlation is
# Top 5 highest correlation is between -
#
# Calories from Fat - Total Fat : 0.99
#
# Total Fat Daily Value.- Total Fat : 0.99
#
# Calories-Total Fat Daily Value : 0.99
#
# Saturated.Fat-Saturated.Fat Daily Value : 0.99
#
# Cholestrol- Cholesterol Daily Value : 0.99

# %% [markdown]
# ## Which item contributes maximum to the Sodium intake?

# %%
McD.groupby('Item')['Sodium'].sum().sort_values(ascending = False)
# Out:
# Item
# Chicken McNuggets (40 piece)                                    3600
# Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)      2290
# Big Breakfast with Hotcakes (Large Biscuit)                     2260
# Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)    2170
# Big Breakfast with Hotcakes (Regular Biscuit)                   2150
#                                                                 ...
# Coca-Cola Classic (Child)                                          0
# Dasani Water Bottle                                                0
# Minute Maid Orange Juice (Medium)                                  0
# Apple Slices                                                       0
# Minute Maid Orange Juice (Small)                                   0
# Name: Sodium, Length: 260, dtype: int64

# %% [markdown]
# ## Which 4 food items contains the most amount of Saturated Fat?

# %%
McD.groupby('Item').sum()['Saturated Fat'].sort_values(ascending = False)
# Out:
# C:\Users\shiba\AppData\Local\Temp\ipykernel_22312\3945177190.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   McD.groupby('Item').sum()['Saturated Fat'].sort_values(ascending = False)
# Item
# McFlurry with M&M’s Candies (Medium)           20.0
# Big Breakfast with Hotcakes (Large Biscuit)    20.0
# Chicken McNuggets (40 piece)                   20.0
# Frappé Chocolate Chip (Large)                  20.0
# Double Quarter Pounder with Cheese             19.0
#                                                ...
# Diet Dr Pepper (Small)                          0.0
# Diet Dr Pepper (Medium)                         0.0
# Diet Dr Pepper (Large)                          0.0
# Diet Dr Pepper (Child)                          0.0
# Minute Maid Orange Juice (Large)                0.0
# ...

# %% [markdown]
# ##  Which category contributes to the maximum % of Cholesterol in a diet (% daily value)?

# %%
McD.groupby('Category').sum()['Cholesterol (% Daily Value)'].sort_values(ascending = False)
# Out:
# C:\Users\shiba\AppData\Local\Temp\ipykernel_22312\3904724373.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   McD.groupby('Category').sum()['Cholesterol (% Daily Value)'].sort_values(ascending = False)
# Category
# Breakfast             2140
# Coffee & Tea           891
# Chicken & Fish         681
# Beef & Pork            434
# Smoothies & Shakes     412
# Salads                 104
# Snacks & Sides          81
# Desserts                34
# Beverages                5
# Name: Cholesterol (% Daily Value), dtype: int64

# %%
### The End
